# %% [markdown]
# For Week 4 I have to answer to questions below
#
# #### 1) A description of the problem and a discussion of the background. (15 marks)
#
# #### 2) A description of the data and how it will be used to solve the problem. (15 marks)

# %% [markdown]
# Okay let's start with the first question

# %% [markdown]
# #### 1) A Description of the problem and a discussion of the background

# %% [markdown]
# "Which store,shop or restaurant in Baltimore, MD, USA has the most incident?"
#
# "Show some basic statistics, what type of crime happened by the type of store?
#
# "Visualize Top 5 dangerous store,shop or restaurant in each neighborhood by utilizing Foursquare data and baltimore crime data"

# %% [markdown]
# #### 2) A description of the data and how it will be used to solve the problem

# %% [markdown]
# Baltimore Zipcode: http://ciclt.net/sn/clt/capitolimpact/gw_ziplist.aspx?ClientCode=capitolimpact&State=md&StName=Georgia&StFIPS=13&FIPS=24510

# %% [markdown]
# Baltimore Crime Data : https://data.baltimorecity.gov/datasets/part1-crime-data/explore?location=39.300436%2C-76.606438%2C11.36&showTable=true

# %% [markdown]
# ## We are ready to start the project. The project compose with 4 steps
# ### 0) Import all the neccessary libraries
# ### 1) Play around and clean "Baltimore Crime Data"
# ### 2) Play around and clean "Baltimore FourSquare Data"
# ### 3) Combine two data
# ### 4) Visualize with folium

# %%
import numpy as np
import pandas as pd
import csv
import requests
import folium
import json
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
from pandas.io.json import json_normalize
print('Libraries imported')
# Out:
# Libraries imported

# %% [markdown]
# Awesome step 0 done. Start indicates half done.

# %% [markdown]
# # Step 1) Play around and clean "Baltimore Crime Data"

# %%
# Bring CSV file and make a data frame out of it
crime_df = pd.read_csv (r'/Users/gihonglee/Downloads/Part1_Crime_data.csv')
crime_df.head(5)
# Out:
#               X              Y  RowID           CrimeDateTime CrimeCode  \
# 0  1.424294e+06  599933.502296      1  2021/07/31 09:06:21+00        1A
# 1  1.422335e+06  601637.004732      2  2021/07/31 14:30:00+00        6L
# 2  1.402984e+06  609174.437883      3  2021/07/31 21:00:00+00        6D
# 3  1.424228e+06  569446.823751      4  2021/07/31 01:00:00+00        6D
# 4  1.413008e+06  599194.993195      5  2021/07/31 12:30:00+00        4E
#
#                 Location        Description Inside_Outside   Weapon Post  \
# 0       2000 KENNEDY AVE           HOMICIDE         Inside  FIREARM  312
# 1          400 E 25TH ST            LARCENY         Inside      NaN  513
# 2      3800 DOLFIELD AVE  LARCENY FROM AUTO            NaN      NaN  625
# 3            4300 5TH ST  LARCENY FROM AUTO         Inside      NaN  913
# 4  2600 PENNSYLVANIA AVE     COMMON ASSAULT        Outside      NaN  733
#
#     District           Neighborhood  Latitude  Longitude         GeoLocation  \
# 0    EASTERN  EAST BALTIMORE MIDWAY   39.3133   -76.6043  (39.3133,-76.6043)
# 1   NORTHERN                BARCLAY   39.3180   -76.6112   (39.318,-76.6112)
# 2  NORTHWEST               DOLFIELD   39.3389   -76.6795  (39.3389,-76.6795)
# 3   SOUTHERN               BROOKLYN   39.2296   -76.6050   (39.2296,-76.605)
# 4    WESTERN             PENN NORTH   39.3114   -76.6442  (39.3114,-76.6442)
#
#                 Premise    VRIName  Total_Incidents  Shape
# 0       VACANT DWELLING  Eastern 1                1    NaN
# 1  STREET                      NaN                1    NaN
# 2                   NaN        NaN                1    NaN
# 3  STREET                      NaN                1    NaN
# 4     OTHER/RESIDENTIAL    Western                1    NaN

# %% [markdown]
# Let me clean the data

# %%
crime_df = crime_df.drop(columns = ['X','Y','RowID','CrimeCode','Weapon','Post','GeoLocation','Premise','VRIName','Total_Incidents','Shape'])

# %%
crime_df.head(5)
# Out:
#             CrimeDateTime               Location        Description  \
# 0  2021/07/31 09:06:21+00       2000 KENNEDY AVE           HOMICIDE
# 1  2021/07/31 14:30:00+00          400 E 25TH ST            LARCENY
# 2  2021/07/31 21:00:00+00      3800 DOLFIELD AVE  LARCENY FROM AUTO
# 3  2021/07/31 01:00:00+00            4300 5TH ST  LARCENY FROM AUTO
# 4  2021/07/31 12:30:00+00  2600 PENNSYLVANIA AVE     COMMON ASSAULT
#
#   Inside_Outside   District           Neighborhood  Latitude  Longitude
# 0         Inside    EASTERN  EAST BALTIMORE MIDWAY   39.3133   -76.6043
# 1         Inside   NORTHERN                BARCLAY   39.3180   -76.6112
# 2            NaN  NORTHWEST               DOLFIELD   39.3389   -76.6795
# 3         Inside   SOUTHERN               BROOKLYN   39.2296   -76.6050
# 4        Outside    WESTERN             PENN NORTH   39.3114   -76.6442

# %%
# Clean the crimeDateTime
crime_df["CrimeDateTime"] = crime_df["CrimeDateTime"].astype(str).str[0:10]

# %% [markdown]
# Drop na rows

# %%
print(crime_df.shape)
crime_df = crime_df.dropna()
print(crime_df.shape)
print("Data has been cleaned")
# Out:
# (343727, 8)
# (296487, 8)
# Data has been cleaned

# %%
crime_df.head(5)
# Out:
#   CrimeDateTime               Location        Description Inside_Outside  \
# 0    2021/07/31       2000 KENNEDY AVE           HOMICIDE         Inside
# 1    2021/07/31          400 E 25TH ST            LARCENY         Inside
# 3    2021/07/31            4300 5TH ST  LARCENY FROM AUTO         Inside
# 4    2021/07/31  2600 PENNSYLVANIA AVE     COMMON ASSAULT        Outside
# 5    2021/07/31        2700 RAYNER AVE     COMMON ASSAULT        Outside
#
#    District           Neighborhood  Latitude  Longitude
# 0   EASTERN  EAST BALTIMORE MIDWAY   39.3133   -76.6043
# 1  NORTHERN                BARCLAY   39.3180   -76.6112
# 3  SOUTHERN               BROOKLYN   39.2296   -76.6050
# 4   WESTERN             PENN NORTH   39.3114   -76.6442
# 5   WESTERN                 MOSHER   39.2964   -76.6616

# %% [markdown]
# #### Let's manaually create the latitude and longitude of neighborhood by getting the mean value of lat and lng

# %%
hood_coor = crime_df.groupby(by = "Neighborhood").mean()
hood_coor.reset_index(inplace = True)
hood_coor[hood_coor["Neighborhood"] == "BROOKLYN"]
# Out:
#    Neighborhood   Latitude  Longitude
# 26     BROOKLYN  39.233851 -76.603065

# %% [markdown]
# # 2) Play around and clean "Baltimore FourSquare Data"

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'GHM3DHK0SNYALRT1CZTQOFEU4BRENGUSVM451QCG4E2JFDVS' # your Foursquare ID
CLIENT_SECRET = 'X2PMXTL3HGU1JQXJVJKCKXCLITPC4024TFPUTXNODZV25Z5S' # your Foursquare Secret
VERSION = '20180604' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: GHM3DHK0SNYALRT1CZTQOFEU4BRENGUSVM451QCG4E2JFDVS
# CLIENT_SECRET:X2PMXTL3HGU1JQXJVJKCKXCLITPC4024TFPUTXNODZV25Z5S

# %% [markdown]
# First of all let's try to get top 100 venues from a location.
# For the convience, let's pick a location to be Downtown

# %%
lat = 39.2895
lng = -76.6151

# %%
LIMIT = 100
radius = 500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    lat,
    lng, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=GHM3DHK0SNYALRT1CZTQOFEU4BRENGUSVM451QCG4E2JFDVS&client_secret=X2PMXTL3HGU1JQXJVJKCKXCLITPC4024TFPUTXNODZV25Z5S&v=20180604&ll=39.2895,-76.6151&radius=500&limit=100'

# %% [markdown]
# Send the GET request and examine the resutls

# %%
results = requests.get(url).json()

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
    
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# #### Let's create a function to repeat the same process to all the neighborhoods in Baltimore

# %%
def getNearbyVenues(names, lats, lngs, radius = 500):
    
    nearby_venues_columns = ['Neighborhood',
                            'Neighborhood Latitude',
                            'Neighborhood Longitude',
                            'Venue',
                            'Venue Latitude',
                            'Venue Longitude',
                            'Venue Address',
                            'Venue Category']
    nearby_venues = pd.DataFrame(columns = nearby_venues_columns)
    filtered_columns = ['venue.name','venue.location.lat','venue.location.lng','venue.location.address','venue.categories']

    for name, lat, lng in zip(names, lats, lngs):
   
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        
        # make the GET request
        results = requests.get(url).json()['response']['groups'][0]['items']
        nearby_venues_table = json_normalize(results)
        if set(filtered_columns).issubset(set(nearby_venues_table.columns)):
            nearby_venues_table = nearby_venues_table[filtered_columns]
            nearby_venues_table['venue.categories'] = nearby_venues_table.apply(get_category_type, axis = 1)
            nearby_venues_table.insert(loc = 0, column = "lng", value = lng)
            nearby_venues_table.insert(loc = 0, column = "lat", value = lat)
            nearby_venues_table.insert(loc = 0, column = "name", value = name)
            nearby_venues_table.rename(columns = dict(zip(nearby_venues_table.columns, nearby_venues_columns)),inplace = True)
            nearby_venues = nearby_venues.append(nearby_venues_table)
            #print(nearby_venues.shape)
    
        # return only relevant information for each nearby venue
        
#         venues_list.append([(
#             name,
#             lat,
#             lng,
#             v['venue']['name'],
#             v['venue']['location']['lat'],
#             v['venue']['location']['lng'],
#             v['venue']['location']['address'],
#             v['venue']['categories'][0]['name']) for v in results])
  
    
    

    return(nearby_venues)

# %%
a = getNearbyVenues(hood_coor["Neighborhood"], hood_coor["Latitude"], hood_coor["Longitude"], radius = 500)

# %% [markdown]
# #### Finally we got the baltimore store data!! Part2 Done!

# %%
baltimore_store = a
baltimore_store.head(5)
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0        ABELL              39.326032              -76.610699
# 1        ABELL              39.326032              -76.610699
# 2        ABELL              39.326032              -76.610699
# 3        ABELL              39.326032              -76.610699
# 4        ABELL              39.326032              -76.610699
#
#                          Venue  Venue Latitude  Venue Longitude  \
# 0  32nd Street Farmer's Market       39.327362       -76.610851
# 1                Pete's Grille       39.327064       -76.609593
# 2               The Book Thing       39.325253       -76.610272
# 3     Normal's Books & Records       39.326012       -76.609903
# 4      Peabody Heights Brewery       39.324744       -76.610819
#
#          Venue Address  Venue Category
# 0        400 E 32nd St  Farmers Market
# 1  3130 Greenmount Ave  Breakfast Spot
# 2     3001 Vineyard Ln       Bookstore
# 3        425 E 31st St     Record Shop
# 4        401 E 30th St         Brewery

# %% [markdown]
# ## Part 3) Let's try to Combine two data
# #### Before combining let's recap what data we have

# %%
# Baltimore Crime Data
crime_df.head(3)
# Baltimore Store Data
#baltimore_store.head(3)
# Out:
#   CrimeDateTime          Location        Description Inside_Outside  District  \
# 0    2021/07/31  2000 KENNEDY AVE           HOMICIDE         Inside   EASTERN
# 1    2021/07/31     400 E 25TH ST            LARCENY         Inside  NORTHERN
# 3    2021/07/31       4300 5TH ST  LARCENY FROM AUTO         Inside  SOUTHERN
#
#             Neighborhood  Latitude  Longitude
# 0  EAST BALTIMORE MIDWAY   39.3133   -76.6043
# 1                BARCLAY   39.3180   -76.6112
# 3               BROOKLYN   39.2296   -76.6050

# %% [markdown]
# #### we can either compare by street name which is -> 1) crime_df[Location] & baltimore_store[Venue]
# #### or we can compare by the coordinate of the location.
# #### Either way, we need to clean the data. So let's
# #### step 1) clean the data for the location
# #### step 2) see how many overlap is there between crime and store data

# %%
# so first let's make all upper letter for the venue address of store data
baltimore_store["Venue Address"] = baltimore_store["Venue Address"].str.upper()
baltimore_store["Location"] = baltimore_store["Venue Address"]

# %%
baltimore_store["Venue Address"]
print(crime_df.shape)
merge_df = crime_df.merge(baltimore_store, how='inner', on='Location')
print(merge_df.shape)
# Out:
# (296487, 8)
# (31355, 16)

# %% [markdown]
# It is interesting out of 296,487 crime cases, 31,355 cases were happend either on store or outside of the store

# %% [markdown]
# However, before going to the further analysis, let's clean the data a little bit.

# %%
merge_df.tail(5)
# Out:
#       CrimeDateTime              Location Description Inside_Outside  \
# 31350    2019/12/24  500 W COLD SPRING LN    BURGLARY              I
# 31351    2019/12/24  500 W COLD SPRING LN    BURGLARY              I
# 31352    2019/12/24  500 W COLD SPRING LN    BURGLARY              I
# 31353    2020/07/31       REISTERSTOWN RD    BURGLARY              I
# 31354    2020/05/31  400 W COLD SPRING LN    BURGLARY              I
#
#         District        Neighborhood_x  Latitude  Longitude Neighborhood_y  \
# 31350   NORTHERN               KESWICK   39.3445   -76.6311      EVERGREEN
# 31351   NORTHERN               KESWICK   39.3445   -76.6311        KESWICK
# 31352   NORTHERN               KESWICK   39.3445   -76.6311    ROLAND PARK
# 31353  NORTHWEST  REISTERSTOWN STATION   39.3563   -76.7028   LUCILLE PARK
# 31354   NORTHERN               KESWICK   39.3446   -76.6305        KESWICK
#
#        Neighborhood Latitude  Neighborhood Longitude  \
# 31350              39.345547              -76.628235
# 31351              39.343444              -76.630594
# 31352              39.345305              -76.634957
# 31353              39.340572              -76.675024
# 31354              39.343444              -76.630594
#
#                                  Venue  Venue Latitude  Venue Longitude  \
# 31350            Roland Park Bagel Co.       39.344612       -76.631178
# 31351            Roland Park Bagel Co.       39.344612       -76.631178
# 31352            Roland Park Bagel Co.       39.344612       -76.631178
# 31353  Valley Village Wine and Spirits       39.339379       -76.680155
# 31354    Video Americain - Roland Park       39.343859       -76.635222
#
#               Venue Address Venue Category
# 31350  500 W COLD SPRING LN     Bagel Shop
# 31351  500 W COLD SPRING LN     Bagel Shop
# 31352  500 W COLD SPRING LN     Bagel Shop
# 31353       REISTERSTOWN RD   Liquor Store
# 31354  400 W COLD SPRING LN    Video Store

# %%
merge_col = ["CrimeDateTime", "Location", "Description", "Inside_Outside", "Latitude", "Longitude","Venue","Venue Category"]
merge_df = merge_df[merge_col]
merge_df.head(5)
# Out:
#   CrimeDateTime          Location        Description Inside_Outside  Latitude  \
# 0    2021/07/31  5800 EASTERN AVE       AGG. ASSAULT         Inside   39.2875
# 1    2018/08/19  5800 EASTERN AVE     COMMON ASSAULT              I   39.2875
# 2    2018/07/28  5800 EASTERN AVE     COMMON ASSAULT              O   39.2875
# 3    2018/06/18  5800 EASTERN AVE     COMMON ASSAULT              O   39.2875
# 4    2017/08/26  5800 EASTERN AVE  LARCENY FROM AUTO              O   39.2875
#
#    Longitude             Venue      Venue Category
# 0   -76.5464  La Bamba Liquors  Mexican Restaurant
# 1   -76.5464  La Bamba Liquors  Mexican Restaurant
# 2   -76.5461  La Bamba Liquors  Mexican Restaurant
# 3   -76.5464  La Bamba Liquors  Mexican Restaurant
# 4   -76.5464  La Bamba Liquors  Mexican Restaurant

# %%
print(merge_df.Inside_Outside.unique())
merge_df.replace({"Inside" : "I", "Outside" : "O"}, inplace = True)
merge_df.groupby(by = "Inside_Outside").count()
# Out:
# ['Inside' 'I' 'O' 'Outside']
#                 CrimeDateTime  Location  Description  Latitude  Longitude  \
# Inside_Outside
# I                       19824     19824        19824     19824      19824
# O                       11531     11531        11531     11531      11531
#
#                 Venue  Venue Category
# Inside_Outside
# I               19824           19824
# O               11531           11531

# %%
19824/(19824+11531)
# Out:
# 0.6322436612980386

# %% [markdown]
# #### Around 63% percent of crime happened inside of the store and 37% of the crime happend outside of the store.

# %% [markdown]
# Now let's see 1) what type of store has been involved in crime
# 2) Top 2 notorious store in the baltimore

# %%
#1) what type of store is fragile to crime

# %%
merge_df.groupby(by = "Venue Category").count().sort_values(by = "CrimeDateTime", ascending = False).head(10)
# Out:
#                     CrimeDateTime  Location  Description  Inside_Outside  \
# Venue Category
# Pharmacy                     2779      2779         2779            2779
# Bus Station                  2548      2548         2548            2548
# Metro Station                1929      1929         1929            1929
# Coffee Shop                  1509      1509         1509            1509
# Grocery Store                1224      1224         1224            1224
# Hotel                        1041      1041         1041            1041
# Seafood Restaurant            810       810          810             810
# Convenience Store             794       794          794             794
# Supplement Shop               684       684          684             684
# Department Store              662       662          662             662
#
#                     Latitude  Longitude  Venue
# Venue Category
# Pharmacy                2779       2779   2779
# Bus Station             2548       2548   2548
# Metro Station           1929       1929   1929
# Coffee Shop             1509       1509   1509
# Grocery Store           1224       1224   1224
# Hotel                   1041       1041   1041
# Seafood Restaurant       810        810    810
# Convenience Store        794        794    794
# Supplement Shop          684        684    684
# Department Store         662        662    662

# %% [markdown]
# Not quite sure why Pharmacy is the place that crime happend the most. let's take a deeper look into it.

# %%
phar_df = merge_df[merge_df["Venue Category"] == "Pharmacy"]
phar_df.groupby(by = "Description").count().sort_values(by = "Location")
# Out:
#                       CrimeDateTime  Location  Inside_Outside  Latitude  \
# Description
# ROBBERY - CARJACKING              3         3               3         3
# ROBBERY - RESIDENCE              10        10              10        10
# RAPE                             17        17              17        17
# SHOOTING                         46        46              46        46
# AUTO THEFT                       77        77              77        77
# LARCENY FROM AUTO                98        98              98        98
# ROBBERY - STREET                115       115             115       115
# BURGLARY                        152       152             152       152
# ROBBERY - COMMERCIAL            160       160             160       160
# AGG. ASSAULT                    229       229             229       229
# COMMON ASSAULT                  403       403             403       403
# LARCENY                        1469      1469            1469      1469
#
#                       Longitude  Venue  Venue Category
# Description
# ROBBERY - CARJACKING          3      3               3
# ROBBERY - RESIDENCE          10     10              10
# RAPE                         17     17              17
# SHOOTING                     46     46              46
# AUTO THEFT                   77     77              77
# LARCENY FROM AUTO            98     98              98
# ROBBERY - STREET            115    115             115
# BURGLARY                    152    152             152
# ROBBERY - COMMERCIAL        160    160             160
# AGG. ASSAULT                229    229             229
# COMMON ASSAULT              403    403             403
# LARCENY                    1469   1469            1469

# %% [markdown]
# Aha I guess due to running 24hours, the crime happens often at night. In order to prove this I have to get the time data from the original and do more analysis but,,,, let's move on for now

# %% [markdown]
# #### Now let's see which store is the "Notorious store"

# %%
c_df = merge_df.groupby(by = "Location").count().sort_values(by = "Venue", ascending = False)

c_df["percent"] = (c_df['CrimeDateTime'] / c_df['CrimeDateTime'].sum()) * 100
c_df.reset_index(inplace = True)
final_df = pd.merge(c_df, merge_df.groupby("Location",as_index=False).first(), left_on='Location', right_on='Location', how='left')
columns = ["Location", "CrimeDateTime_x","Latitude_y", "Longitude_y","Venue_y","Venue Category_y" ,"Description_y"]
final_df = final_df[columns]
new_col = ["Location", "Num_Crime","Lat", "Lng","Venue","Category","Desc"]
final_df.rename(columns=dict(zip(columns,new_col)), inplace = True)

# %% [markdown]
# ## 4) Visualize with folium

# %%
final_df.head()
final_df["Num_Crime"].mean()
final_df.head(10)
# Out:
#                    Location  Num_Crime      Lat      Lng  \
# 0  2400 LIBERTY HEIGHTS AVE       4459  39.3186 -76.6540
# 1            200 E PRATT ST       3354  39.2866 -76.6121
# 2            400 E PRATT ST       1415  39.2867 -76.6099
# 3              300 LIGHT ST       1116  39.2851 -76.6131
# 4              5200 YORK RD        995  39.3540 -76.6098
# 5      1800 WASHINGTON BLVD        812  39.2753 -76.6422
# 6    2000 GWYNNS FALLS PKWY        748  39.3159 -76.6522
# 7            600 E PRATT ST        662  39.2868 -76.6077
# 8         3800 E LOMBARD ST        602  39.2916 -76.5649
# 9        4500 EDMONDSON AVE        588  39.2933 -76.6910
#
#                                   Venue          Category  \
# 0               Mondawmin Metro Station     Metro Station
# 1                     Bath & Body Works    Cosmetics Shop
# 2                           Shake Shack      Burger Joint
# 3  Hyatt Regency Baltimore Inner Harbor             Hotel
# 4                          CVS pharmacy          Pharmacy
# 5                               Dunkin'              Café
# 6                  Shoppers Food Market     Grocery Store
# 7                             Marshalls  Department Store
# 8             Hazlo International Foods     Grocery Store
# 9                        Dollar General    Discount Store
#
#                    Desc
# 0               LARCENY
# 1               LARCENY
# 2               LARCENY
# 3               LARCENY
# 4               LARCENY
# 5               LARCENY
# 6  ROBBERY - COMMERCIAL
# 7        COMMON ASSAULT
# 8  ROBBERY - COMMERCIAL
# 9               LARCENY

# %%
# Now it is the time to do some visualization! 
# I want to do it so that the latitude with the high crime to have a bigger circle and low crime to have smaller circle
# first of all let's set the latitude and longitude, for the convience, we will just go by the mean of final df
lat = final_df["Lat"].mean()
lng = final_df["Lng"].mean()

# create map
map_clusters = folium.Map(location = [lat, lng], zoom_start = 11)
# set color scheme for the clusters

#x = np.arange(kclusters)
#ys = [i +x + (i*x)**2 for i in range(kclusters)]
#colors_array = cm.rainbow(np.linspace(0,1, len(ys)))
#rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the maps
#markers_colors = []
for lat, lon, ven, Desc, mag in zip(final_df['Lat'], final_df['Lng'],\
                                 final_df['Venue'],final_df['Desc'], final_df['Num_Crime']):
    label = folium.Popup(ven + " - " + Desc , parse_html = True)
    folium.CircleMarker(
        [lat, lon],
        radius = (mag+300)/300,
        popup = label,
        color = 'red',
        fill = True,
        fill_color = 'red',
        fill_opacity = 0.7).add_to(map_clusters)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_39aab175ec2242c09afdfa11b9a434be%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_39aab175ec2242c09afdfa11b9a434be%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_39aab175ec2242c09afdfa11b9a434be%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_39aab175ec2242c09afdfa11b9a434be%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B39.302448058252416%2C-76.6144412621359%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20 ...
